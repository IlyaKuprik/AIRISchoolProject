# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !tar -xvzf /content/drive/MyDrive/Sejong.tgz
! unzip /content/drive/MyDrive/airi_dataset.zip

# %%
# !pip install wandb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting wandb
#   Downloading wandb-0.12.21-py2.py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 28.9 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from wandb) (57.4.0)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (7.1.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from wandb) (3.13)
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.9-py3-none-any.whl (9.4 kB)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 71.5 MB/s
# Collecting setproctitle
#   Downloading setproctitle-1.2.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29 kB)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.15.0)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.3)
# Requirement already satisfied: protobuf<4.0dev,>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.17.3)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (5.4.8)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.6.0-py2.py3-none-any.whl (145 kB)
#      |████████████████████████████████| 145 kB 74.6 MB/s
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.23.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb) (4.1.1)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 531 kB/s
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Building wheels for collected packages: pathtools
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=b184c14194ccccf25de1893e021d3f8d65c8d317fb996d79d8e50ef7aca9b599
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built pathtools
# Installing collected packages: smmap, gitdb, shortuuid, setproctitle, sentry-sdk, pathtools, GitPython, docker-pycreds, wandb
# Successfully installed GitPython-3.1.27 docker-pycreds-0.4.0 gitdb-4.0.9 pathtools-0.1.2 sentry-sdk-1.6.0 setproctitle-1.2.3 shortuuid-1.0.9 smmap-5.0.0 wandb-0.12.21

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import tensorflow as tf

from torch.autograd import Variable
from torchvision.models import resnet18

# from keras.preprocessing import image

import PIL
import torch
import torchvision

import matplotlib.pyplot as plt
from sklearn import metrics
import wandb
import tqdm
import json

RANDOM_SEED = 777

torch.manual_seed(RANDOM_SEED)

with open('/content/airi_dataset/metainfo.json') as fin:
    metainfo = json.load(fin)

num_to_class = metainfo['num_to_class']

train_size = metainfo['data']['train_size']
test_size = metainfo['data']['test_size']
val_size = metainfo['data']['val_size']

classes_count = len(num_to_class)

# %%
from PIL import Image
from sklearn import (manifold, datasets, decomposition, ensemble,
                     discriminant_analysis, random_projection)
import torchvision.transforms.functional as Function
from IPython.display import display
from time import time
from matplotlib import offsetbox
from sklearn.neighbors import DistanceMetric
# %matplotlib inline

# %% [markdown]
# ## NetVLAD

# %%
class NetVLAD(nn.Module):
    """NetVLAD layer implementation"""

    def __init__(self, num_clusters=6, dim=128, alpha=100.0,
                 normalize_input=True):
        """
        Args:
            num_clusters : int
                The number of clusters
            dim : int
                Dimension of descriptors
            alpha : float
                Parameter of initialization. Larger value is harder assignment.
            normalize_input : bool
                If true, descriptor-wise L2 normalization is applied to input.
        """
        super(NetVLAD, self).__init__()
        self.num_clusters = num_clusters
        self.dim = dim
        self.alpha = alpha
        self.normalize_input = normalize_input
        self.conv = nn.Conv2d(dim, num_clusters, kernel_size=(1, 1), bias=True)
        self.centroids = nn.Parameter(torch.rand(num_clusters, dim))
        self._init_params()

    def _init_params(self):
        self.conv.weight = nn.Parameter(
            (2.0 * self.alpha * self.centroids).unsqueeze(-1).unsqueeze(-1)
        )
        self.conv.bias = nn.Parameter(
            - self.alpha * self.centroids.norm(dim=1)
        )

    def forward(self, x):
        N, C = x.shape[:2]

        if self.normalize_input:
            x = F.normalize(x, p=2, dim=1)  # across descriptor dim

        # soft-assignment
        soft_assign = self.conv(x).view(N, self.num_clusters, -1)
        soft_assign = F.softmax(soft_assign, dim=1)

        x_flatten = x.view(N, C, -1)
        
        # calculate residuals to each clusters
        residual = x_flatten.expand(self.num_clusters, -1, -1, -1).permute(1, 0, 2, 3) - \
            self.centroids.expand(x_flatten.size(-1), -1, -1).permute(1, 2, 0).unsqueeze(0)
        residual *= soft_assign.unsqueeze(2)
        vlad = residual.sum(dim=-1)

        vlad = F.normalize(vlad, p=2, dim=2)  # intra-normalization
        vlad = vlad.view(x.size(0), -1)  # flatten
        vlad = F.normalize(vlad, p=2, dim=1)  # L2 normalize

        return vlad

# %%
class EmbedNet(nn.Module):
    def __init__(self, base_model, net_vlad):
        super(EmbedNet, self).__init__()
        self.base_model = base_model
        self.net_vlad = net_vlad

    def forward(self, x):
        x = self.base_model(x)
        embedded_x = self.net_vlad(x)
        return embedded_x
      
class TripletNet(nn.Module):
    def __init__(self, embed_net):
        super(TripletNet, self).__init__()
        self.embed_net = embed_net

    def forward(self, a, p, n):
        embedded_a = self.embed_net(a)
        embedded_p = self.embed_net(p)
        embedded_n = self.embed_net(n)
        return embedded_a, embedded_p, embedded_n

    def feature_extract(self, x):
        return self.embed_net(x)

# %%
class HardTripletLoss(nn.Module):
    """Hard/Hardest Triplet Loss
    (pytorch implementation of https://omoindrot.github.io/triplet-loss)
    For each anchor, we get the hardest positive and hardest negative to form a triplet.
    """
    def __init__(self, margin=0.1, hardest=False, squared=False):
        """
        Args:
            margin: margin for triplet loss
            hardest: If true, loss is considered only hardest triplets.
            squared: If true, output is the pairwise squared euclidean distance matrix.
                If false, output is the pairwise euclidean distance matrix.
        """
        super(HardTripletLoss, self).__init__()
        self.margin = margin
        self.hardest = hardest
        self.squared = squared

    def forward(self, embeddings, labels):
        """
        Args:
            labels: labels of the batch, of size (batch_size,)
            embeddings: tensor of shape (batch_size, embed_dim)
        Returns:
            triplet_loss: scalar tensor containing the triplet loss
        """
        pairwise_dist = _pairwise_distance(embeddings, squared=self.squared)

        if self.hardest:
            # Get the hardest positive pairs
            mask_anchor_positive = _get_anchor_positive_triplet_mask(labels).float()
            valid_positive_dist = pairwise_dist * mask_anchor_positive
            hardest_positive_dist, _ = torch.max(valid_positive_dist, dim=1, keepdim=True)

            # Get the hardest negative pairs
            mask_anchor_negative = _get_anchor_negative_triplet_mask(labels).float()
            max_anchor_negative_dist, _ = torch.max(pairwise_dist, dim=1, keepdim=True)
            anchor_negative_dist = pairwise_dist + max_anchor_negative_dist * (
                    1.0 - mask_anchor_negative)
            hardest_negative_dist, _ = torch.min(anchor_negative_dist, dim=1, keepdim=True)

            # Combine biggest d(a, p) and smallest d(a, n) into final triplet loss
            triplet_loss = F.relu(hardest_positive_dist - hardest_negative_dist + 0.1)
            triplet_loss = torch.mean(triplet_loss)
        else:
            anc_pos_dist = pairwise_dist.unsqueeze(dim=2)
            anc_neg_dist = pairwise_dist.unsqueeze(dim=1)

            # Compute a 3D tensor of size (batch_size, batch_size, batch_size)
            # triplet_loss[i, j, k] will contain the triplet loss of anc=i, pos=j, neg=k
            # Uses broadcasting where the 1st argument has shape (batch_size, batch_size, 1)
            # and the 2nd (batch_size, 1, batch_size)
            loss = anc_pos_dist - anc_neg_dist + self.margin

            mask = _get_triplet_mask(labels).float()
            triplet_loss = loss * mask

            # Remove negative losses (i.e. the easy triplets)
            triplet_loss = F.relu(triplet_loss)

            # Count number of hard triplets (where triplet_loss > 0)
            hard_triplets = torch.gt(triplet_loss, 1e-16).float()
            num_hard_triplets = torch.sum(hard_triplets)

            triplet_loss = torch.sum(triplet_loss) / (num_hard_triplets + 1e-16)

        return triplet_loss


def _pairwise_distance(x, squared=False, eps=1e-16):
    # Compute the 2D matrix of distances between all the embeddings.

    cor_mat = torch.matmul(x, x.t())
    norm_mat = cor_mat.diag()
    distances = norm_mat.unsqueeze(1) - 2 * cor_mat + norm_mat.unsqueeze(0)
    distances = F.relu(distances)

    if not squared:
        mask = torch.eq(distances, 0.0).float()
        distances = distances + mask * eps
        distances = torch.sqrt(distances)
        distances = distances * (1.0 - mask)

    return distances


def _get_anchor_positive_triplet_mask(labels):
    # Return a 2D mask where mask[a, p] is True iff a and p are distinct and have same label.

    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    indices_not_equal = torch.eye(labels.shape[0]).to(device).byte() ^ 1

    # Check if labels[i] == labels[j]
    labels_equal = torch.unsqueeze(labels, 0) == torch.unsqueeze(labels, 1)

    mask = indices_not_equal * labels_equal

    return mask


def _get_anchor_negative_triplet_mask(labels):
    # Return a 2D mask where mask[a, n] is True iff a and n have distinct labels.

    # Check if labels[i] != labels[k]
    labels_equal = torch.unsqueeze(labels, 0) == torch.unsqueeze(labels, 1)
    mask = labels_equal ^ 1

    return mask


def _get_triplet_mask(labels):
    """Return a 3D mask where mask[a, p, n] is True iff the triplet (a, p, n) is valid.
    A triplet (i, j, k) is valid if:
        - i, j, k are distinct
        - labels[i] == labels[j] and labels[i] != labels[k]
    """
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    # Check that i, j and k are distinct
    indices_not_same = torch.eye(labels.shape[0]).to(device).byte() ^ 1
    i_not_equal_j = torch.unsqueeze(indices_not_same, 2)
    i_not_equal_k = torch.unsqueeze(indices_not_same, 1)
    j_not_equal_k = torch.unsqueeze(indices_not_same, 0)
    distinct_indices = i_not_equal_j * i_not_equal_k * j_not_equal_k

    # Check if labels[i] == labels[j] and labels[i] != labels[k]
    label_equal = torch.eq(torch.unsqueeze(labels, 0), torch.unsqueeze(labels, 1))
    i_equal_j = torch.unsqueeze(label_equal, 2)
    i_equal_k = torch.unsqueeze(label_equal, 1)
    valid_labels = i_equal_j * (~i_equal_k)

    mask = distinct_indices * valid_labels   # Combine the two masks

    return mask

# %% [markdown]
# ## Построение модели

# %%
# Discard layers at the end of base network
encoder = resnet18(pretrained=True)
base_model = nn.Sequential(
    encoder.conv1,
    encoder.bn1,
    encoder.relu,
    encoder.maxpool,
    encoder.layer1,
    encoder.layer2,
    encoder.layer3,
    encoder.layer4,
)
dim = list(base_model.parameters())[-1].shape[0]  # last channels (512)

# Define model for embedding
net_vlad = NetVLAD(num_clusters=classes_count, dim=dim, alpha=1.0)
model = EmbedNet(base_model, net_vlad).cuda()
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]

# %%
# Define loss

wandb_config = {"epochs": 200, 
                "batch_size": 32, 
                "learning_rate": 5e-3,
                "momentum": 0.9, 
                "margin": 0.1,
                "classes_count":classes_count}

criterion = HardTripletLoss(margin=wandb_config["margin"]).cuda()
optimizer = torch.optim.SGD(model.parameters(), 
                            lr=wandb_config["learning_rate"], 
                            momentum=wandb_config["momentum"])

# %% [markdown]
# ## Загрузка данных

# %%
transforms_bef = torchvision.transforms.Compose([                       
    torchvision.transforms.Resize((128,128)),               
    torchvision.transforms.ToTensor(),
])

bef_train_imagenet_data = torchvision.datasets.ImageFolder('/content/airi_dataset/train', transform=transforms_bef)
bef_train_data_loader = torch.utils.data.DataLoader(bef_train_imagenet_data,
                                          train_size, #размер всего трейна
                                          shuffle=False,
                                          num_workers=0)

# %%
for bef_train_image,bef_train_label in bef_train_data_loader :
  bef_train_image = bef_train_image
  bef_train_label = bef_train_label

# %% [markdown]
# Dataloaders for test and train

# %%
transforms_train = torchvision.transforms.Compose([
    torchvision.transforms.ColorJitter(brightness=.5, hue=.3),
    torchvision.transforms.RandomGrayscale(),
    torchvision.transforms.RandomCrop((384, 384)),    
    torchvision.transforms.RandomRotation(degrees=(-20, 20), expand=True),                                     
    torchvision.transforms.Resize((128,128)),               
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
])

transforms_test = torchvision.transforms.Compose([                               
    torchvision.transforms.Resize((128,128)),               
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
])

train_imagenet_data = torchvision.datasets.ImageFolder('/content/airi_dataset/train', transform=transforms_train)
train_data_loader = torch.utils.data.DataLoader(train_imagenet_data,
                                          batch_size=wandb_config['batch_size'],
                                          shuffle=True,
                                          num_workers=0,
                                          drop_last=True)
test_imagenet_data = torchvision.datasets.ImageFolder('/content/airi_dataset/test', transform=transforms_test)
test_data_loader = torch.utils.data.DataLoader(test_imagenet_data,
                                          shuffle=False,
                                          batch_size = train_size,#размер теста
                                          num_workers=0)

# %% [markdown]
# Dataloader for validation

# %%
valid_imagenet_data = torchvision.datasets.ImageFolder('/content/airi_dataset/val', transform=transforms_test)
valid_data_loader = torch.utils.data.DataLoader(valid_imagenet_data,
                                          shuffle=False,
                                          batch_size = val_size,#размер валидационного
                                          num_workers=0)

# %% [markdown]
# ## Обучение

# %%
wandb.init(project="NetVLAD-Model",config = wandb_config)
wandb.watch(model)
# Out:
# Finishing last run (ID:vq4mnm6q) before initializing another...
# Successfully finished last run (ID:vq4mnm6q). Initializing new run:<br/>
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/content/wandb/run-20220708_140418-2dv98zyt</code>
# Syncing run <strong><a href="https://wandb.ai/garipovroma/NetVLAD-Model/runs/2dv98zyt" target="_blank">rural-armadillo-11</a></strong> to <a href="https://wandb.ai/garipovroma/NetVLAD-Model" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# []

# %%
def get_response(X_total, top_n=1):
    pairwise_dist_t = _pairwise_distance(X_total)
    pairwise_dist_n = pairwise_dist_t.cpu().detach().numpy()

    pairwise_dist_sort = np.sort(pairwise_dist_n[-1][:-1])
  
    response = []
    for ii in range(top_n):
        idx = np.where( pairwise_dist_n[-1] == pairwise_dist_sort[ii])
        index_in_base = idx[0][0]
        response.append(index_in_base)
    if top_n == 1:
        return response[0]
    return response # массив индексов из базы

# %%
def find_top_n_nearest(X_pred, Y_base, X_val, Y_val, top_n=1):
    Y_pred = []
    for q_i in range(val_size):
        # print(X_val.shape)
        image_query = X_val[q_i].view(1,-1)
        X_total = torch.cat([X_pred, image_query], dim=0)
        response = get_response(X_total, top_n=top_n)
        pred = Y_base[response]
        Y_pred.append(pred)
    return Y_pred

# %%
def validate(model, X_base, Y_base, valid_image, valid_label, metric_funcs, top_n=1):
    metrics = {}
    X_val = model(valid_image.cuda()).cpu().detach()
    Y_val = valid_label
    Y_pred = find_top_n_nearest(X_base, Y_base, X_val, Y_val, top_n=top_n)
    for (name, mf) in metric_funcs:
        metrics[name] = mf(Y_val, Y_pred)
    return metrics

# %%
import os

def save_model(model, epoch):
    if not os.path.exists('/content/checkpoints/'):
        os.mkdir('/content/checkpoints/')
    model_save_name = 'model_{:02d}_epoch.pt'.format(epoch)
    path = f"/content/checkpoints/{model_save_name}" 
    torch.save(model.state_dict(), path)

# %%
metric_funcs = [('accuracy', metrics.accuracy_score), 
                ('recall', (lambda y_true, y_pred: 
                            metrics.recall_score(y_true, y_pred,average='weighted'))),
                ('precision', (lambda y_true, y_pred: 
                            metrics.precision_score(y_true, y_pred,average='weighted')))]

# %%
pbar = tqdm.tqdm(total=wandb_config['epochs'])
for epoch in range(wandb_config['epochs']):
    # обучение
    loss = 0
    for batch_idx, (train_image,train_label) in enumerate(train_data_loader) :
        output_train = model(train_image.cuda())
        triplet_loss = criterion(output_train, train_label.cuda())
        optimizer.zero_grad()
        triplet_loss.backward(retain_graph=True)
        optimizer.step()
        loss += train_image.size(0) * triplet_loss
    wandb.log({"triplet_loss": loss/len(train_data_loader)})

    model.eval() 
    # валидация
    out_train_image = model(bef_train_image.cuda()).cpu().detach()
    X_base = out_train_image
    Y_base = bef_train_label
    for valid_image, valid_label in valid_data_loader: # тут батч вмещает всю валидационную выборку
        metrics_dict = validate(model, X_base, Y_base, valid_image, valid_label, metric_funcs)
        wandb.log(metrics_dict)
    model.train()

    if not (epoch+1)%10:
        save_model(model=model, epoch=epoch)
    pbar.update(1)
    pbar.set_description(f"Training {epoch+1} eposch...")
pbar.close()
# Out:
# Training 1 eposch...:   0%|          | 1/200 [05:37<18:39:49, 337.63s/it]
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
#   0%|          | 1/200 [00:29<1:39:03, 29.87s/it]
# Training 1 eposch...:   0%|          | 1/200 [00:29<1:39:03, 29.87s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 1 eposch...:   1%|          | 2/200 [00:57<1:34:27, 28.62s/it]
# Training 2 eposch...:   1%|          | 2/200 [00:57<1:34:27, 28.62s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 2 eposch...:   2%|▏         | 3/200 [01:25<1:32:28, 28.17s/it]
# Training 3 eposch...:   2%|▏         | 3/200 [01:25<1:32:28, 28.17s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 3 eposch...:   2%|▏         | 4/200 [01:53<1:32:34, 28.34s/it]
# Training 4 eposch...:   2%|▏         | 4/200 [01:53<1:32:34, 28.34s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 4 eposch...:   2%|▎         | 5/200 [02:21<1:31:22, 28.11s/it]
# Training 5 eposch...:   2%|▎         | 5/200 [02:21<1:31:22, 28.11s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 5 eposch...:   3%|▎         | 6/200 [02:49<1:30:20, 27.94s/it]
# Training 6 eposch...:   3%|▎         | 6/200 [02:49<1:30:20, 27.94s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 6 eposch...:   4%|▎         | 7/200 [03:16<1:29:36, 27.86s/it]
# Training 7 eposch...:   4%|▎         | 7/200 [03:16<1:29:36, 27.86s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 7 eposch...:   4%|▍         | 8/200 [03:44<1:29:02, 27.83s/it]
# Training 8 eposch...:   4%|▍         | 8/200 [03:44<1:29:02, 27.83s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 8 eposch...:   4%|▍         | 9/200 [04:12<1:28:36, 27.83s/it]
# Training 9 eposch...:   4%|▍         | 9/200 [04:12<1:28:36, 27.83s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 9 eposch...:   5%|▌         | 10/200 [04:40<1:27:57, 27.78s/it]
# Training 10 eposch...:   5%|▌         | 10/200 [04:40<1:27:57, 27.78s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 10 eposch...:   6%|▌         | 11/200 [05:07<1:27:24, 27.75s/it]
# Training 11 eposch...:   6%|▌         | 11/200 [05:07<1:27:24, 27.75s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 11 eposch...:   6%|▌         | 12/200 [05:36<1:27:30, 27.93s/it]
# Training 12 eposch...:   6%|▌         | 12/200 [05:36<1:27:30, 27.93s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 12 eposch...:   6%|▋         | 13/200 [06:03<1:26:50, 27.86s/it]
# Training 13 eposch...:   6%|▋         | 13/200 [06:03<1:26:50, 27.86s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 13 eposch...:   7%|▋         | 14/200 [06:31<1:25:57, 27.73s/it]
# Training 14 eposch...:   7%|▋         | 14/200 [06:31<1:25:57, 27.73s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 14 eposch...:   8%|▊         | 15/200 [06:58<1:25:20, 27.68s/it]
# Training 15 eposch...:   8%|▊         | 15/200 [06:58<1:25:20, 27.68s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 15 eposch...:   8%|▊         | 16/200 [07:26<1:24:52, 27.68s/it]
# Training 16 eposch...:   8%|▊         | 16/200 [07:26<1:24:52, 27.68s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 16 eposch...:   8%|▊         | 17/200 [07:54<1:24:20, 27.65s/it]
# Training 17 eposch...:   8%|▊         | 17/200 [07:54<1:24:20, 27.65s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 17 eposch...:   9%|▉         | 18/200 [08:21<1:23:50, 27.64s/it]
# Training 18 eposch...:   9%|▉         | 18/200 [08:21<1:23:50, 27.64s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 18 eposch...:  10%|▉         | 19/200 [08:49<1:23:26, 27.66s/it]
# Training 19 eposch...:  10%|▉         | 19/200 [08:49<1:23:26, 27.66s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 19 eposch...:  10%|█         | 20/200 [09:17<1:23:04, 27.69s/it]
# Training 20 eposch...:  10%|█         | 20/200 [09:17<1:23:04, 27.69s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 20 eposch...:  10%|█         | 21/200 [09:44<1:22:32, 27.67s/it]
# Training 21 eposch...:  10%|█         | 21/200 [09:44<1:22:32, 27.67s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 21 eposch...:  11%|█         | 22/200 [10:12<1:22:07, 27.68s/it]
# Training 22 eposch...:  11%|█         | 22/200 [10:12<1:22:07, 27.68s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 22 eposch...:  12%|█▏        | 23/200 [10:40<1:21:30, 27.63s/it]
# Training 23 eposch...:  12%|█▏        | 23/200 [10:40<1:21:30, 27.63s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 23 eposch...:  12%|█▏        | 24/200 [11:07<1:20:57, 27.60s/it]
# Training 24 eposch...:  12%|█▏        | 24/200 [11:07<1:20:57, 27.60s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 24 eposch...:  12%|█▎        | 25/200 [11:35<1:20:34, 27.62s/it]
# Training 25 eposch...:  12%|█▎        | 25/200 [11:35<1:20:34, 27.62s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 25 eposch...:  13%|█▎        | 26/200 [12:02<1:20:02, 27.60s/it]
# Training 26 eposch...:  13%|█▎        | 26/200 [12:02<1:20:02, 27.60s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 26 eposch...:  14%|█▎        | 27/200 [12:30<1:19:35, 27.60s/it]
# Training 27 eposch...:  14%|█▎        | 27/200 [12:30<1:19:35, 27.60s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 27 eposch...:  14%|█▍        | 28/200 [12:58<1:19:12, 27.63s/it]
# Training 28 eposch...:  14%|█▍        | 28/200 [12:58<1:19:12, 27.63s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 28 eposch...:  14%|█▍        | 29/200 [13:25<1:18:41, 27.61s/it]
# Training 29 eposch...:  14%|█▍        | 29/200 [13:25<1:18:41, 27.61s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 29 eposch...:  15%|█▌        | 30/200 [13:53<1:18:12, 27.60s/it]
# Training 30 eposch...:  15%|█▌        | 30/200 [13:53<1:18:12, 27.60s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 30 eposch...:  16%|█▌        | 31/200 [14:20<1:17:48, 27.62s/it]
# Training 31 eposch...:  16%|█▌        | 31/200 [14:20<1:17:48, 27.62s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 31 eposch...:  16%|█▌        | 32/200 [14:48<1:17:22, 27.63s/it]
# Training 32 eposch...:  16%|█▌        | 32/200 [14:48<1:17:22, 27.63s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 32 eposch...:  16%|█▋        | 33/200 [15:16<1:17:29, 27.84s/it]
# Training 33 eposch...:  16%|█▋        | 33/200 [15:16<1:17:29, 27.84s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 33 eposch...:  17%|█▋        | 34/200 [15:44<1:16:50, 27.77s/it]
# Training 34 eposch...:  17%|█▋        | 34/200 [15:44<1:16:50, 27.77s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 34 eposch...:  18%|█▊        | 35/200 [16:11<1:16:08, 27.69s/it]
# Training 35 eposch...:  18%|█▊        | 35/200 [16:11<1:16:08, 27.69s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 35 eposch...:  18%|█▊        | 36/200 [16:39<1:15:30, 27.63s/it]
# Training 36 eposch...:  18%|█▊        | 36/200 [16:39<1:15:30, 27.63s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 36 eposch...:  18%|█▊        | 37/200 [17:07<1:15:01, 27.61s/it]
# Training 37 eposch...:  18%|█▊        | 37/200 [17:07<1:15:01, 27.61s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 37 eposch...:  19%|█▉        | 38/200 [17:34<1:14:33, 27.62s/it]
# Training 38 eposch...:  19%|█▉        | 38/200 [17:34<1:14:33, 27.62s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 38 eposch...:  20%|█▉        | 39/200 [18:02<1:14:20, 27.71s/it]
# Training 39 eposch...:  20%|█▉        | 39/200 [18:02<1:14:20, 27.71s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 39 eposch...:  20%|██        | 40/200 [18:30<1:14:14, 27.84s/it]
# Training 40 eposch...:  20%|██        | 40/200 [18:30<1:14:14, 27.84s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 40 eposch...:  20%|██        | 41/200 [18:58<1:13:53, 27.88s/it]
# Training 41 eposch...:  20%|██        | 41/200 [18:58<1:13:53, 27.88s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 41 eposch...:  21%|██        | 42/200 [19:26<1:13:32, 27.93s/it]
# Training 42 eposch...:  21%|██        | 42/200 [19:26<1:13:32, 27.93s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 42 eposch...:  22%|██▏       | 43/200 [19:54<1:12:54, 27.87s/it]
# Training 43 eposch...:  22%|██▏       | 43/200 [19:54<1:12:54, 27.87s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 43 eposch...:  22%|██▏       | 44/200 [20:22<1:12:15, 27.79s/it]
# Training 44 eposch...:  22%|██▏       | 44/200 [20:22<1:12:15, 27.79s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 44 eposch...:  22%|██▎       | 45/200 [20:49<1:11:40, 27.74s/it]
# Training 45 eposch...:  22%|██▎       | 45/200 [20:49<1:11:40, 27.74s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 45 eposch...:  23%|██▎       | 46/200 [21:17<1:11:04, 27.69s/it]
# Training 46 eposch...:  23%|██▎       | 46/200 [21:17<1:11:04, 27.69s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 46 eposch...:  24%|██▎       | 47/200 [21:44<1:10:27, 27.63s/it]
# Training 47 eposch...:  24%|██▎       | 47/200 [21:44<1:10:27, 27.63s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 47 eposch...:  24%|██▍       | 48/200 [22:12<1:10:02, 27.65s/it]
# Training 48 eposch...:  24%|██▍       | 48/200 [22:12<1:10:02, 27.65s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 48 eposch...:  24%|██▍       | 49/200 [22:40<1:09:30, 27.62s/it]
# Training 49 eposch...:  24%|██▍       | 49/200 [22:40<1:09:30, 27.62s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 49 eposch...:  25%|██▌       | 50/200 [23:07<1:09:08, 27.66s/it]
# Training 50 eposch...:  25%|██▌       | 50/200 [23:07<1:09:08, 27.66s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 50 eposch...:  26%|██▌       | 51/200 [23:35<1:08:41, 27.66s/it]
# Training 51 eposch...:  26%|██▌       | 51/200 [23:35<1:08:41, 27.66s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 51 eposch...:  26%|██▌       | 52/200 [24:02<1:08:05, 27.60s/it]
# Training 52 eposch...:  26%|██▌       | 52/200 [24:02<1:08:05, 27.60s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 52 eposch...:  26%|██▋       | 53/200 [24:31<1:08:02, 27.77s/it]
# Training 53 eposch...:  26%|██▋       | 53/200 [24:31<1:08:02, 27.77s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 53 eposch...:  27%|██▋       | 54/200 [24:59<1:07:52, 27.89s/it]
# Training 54 eposch...:  27%|██▋       | 54/200 [24:59<1:07:52, 27.89s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 54 eposch...:  28%|██▊       | 55/200 [25:27<1:07:47, 28.05s/it]
# Training 55 eposch...:  28%|██▊       | 55/200 [25:27<1:07:47, 28.05s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 55 eposch...:  28%|██▊       | 56/200 [25:55<1:06:54, 27.88s/it]
# Training 56 eposch...:  28%|██▊       | 56/200 [25:55<1:06:54, 27.88s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 56 eposch...:  28%|██▊       | 57/200 [26:22<1:06:19, 27.83s/it]
# Training 57 eposch...:  28%|██▊       | 57/200 [26:22<1:06:19, 27.83s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 57 eposch...:  29%|██▉       | 58/200 [26:50<1:05:36, 27.72s/it]
# Training 58 eposch...:  29%|██▉       | 58/200 [26:50<1:05:36, 27.72s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 58 eposch...:  30%|██▉       | 59/200 [27:18<1:05:10, 27.74s/it]
# Training 59 eposch...:  30%|██▉       | 59/200 [27:18<1:05:10, 27.74s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 59 eposch...:  30%|███       | 60/200 [27:45<1:04:40, 27.72s/it]
# Training 60 eposch...:  30%|███       | 60/200 [27:45<1:04:40, 27.72s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 60 eposch...:  30%|███       | 61/200 [28:13<1:04:08, 27.69s/it]
# Training 61 eposch...:  30%|███       | 61/200 [28:13<1:04:08, 27.69s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 61 eposch...:  31%|███       | 62/200 [28:40<1:03:35, 27.65s/it]
# Training 62 eposch...:  31%|███       | 62/200 [28:40<1:03:35, 27.65s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 62 eposch...:  32%|███▏      | 63/200 [29:08<1:03:16, 27.71s/it]
# Training 63 eposch...:  32%|███▏      | 63/200 [29:08<1:03:16, 27.71s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 63 eposch...:  32%|███▏      | 64/200 [29:36<1:02:37, 27.63s/it]
# Training 64 eposch...:  32%|███▏      | 64/200 [29:36<1:02:37, 27.63s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 64 eposch...:  32%|███▎      | 65/200 [30:03<1:02:09, 27.63s/it]
# Training 65 eposch...:  32%|███▎      | 65/200 [30:03<1:02:09, 27.63s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 65 eposch...:  33%|███▎      | 66/200 [30:31<1:01:45, 27.65s/it]
# Training 66 eposch...:  33%|███▎      | 66/200 [30:31<1:01:45, 27.65s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 66 eposch...:  34%|███▎      | 67/200 [30:59<1:01:10, 27.60s/it]
# Training 67 eposch...:  34%|███▎      | 67/200 [30:59<1:01:10, 27.60s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 67 eposch...:  34%|███▍      | 68/200 [31:26<1:00:38, 27.57s/it]
# Training 68 eposch...:  34%|███▍      | 68/200 [31:26<1:00:38, 27.57s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 68 eposch...:  34%|███▍      | 69/200 [31:54<1:00:18, 27.62s/it]
# Training 69 eposch...:  34%|███▍      | 69/200 [31:54<1:00:18, 27.62s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 69 eposch...:  35%|███▌      | 70/200 [32:22<59:57, 27.68s/it]
# Training 70 eposch...:  35%|███▌      | 70/200 [32:22<59:57, 27.68s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 70 eposch...:  36%|███▌      | 71/200 [32:49<59:29, 27.67s/it]
# Training 71 eposch...:  36%|███▌      | 71/200 [32:49<59:29, 27.67s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 71 eposch...:  36%|███▌      | 72/200 [33:17<59:08, 27.72s/it]
# Training 72 eposch...:  36%|███▌      | 72/200 [33:17<59:08, 27.72s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 72 eposch...:  36%|███▋      | 73/200 [33:45<58:36, 27.69s/it]
# Training 73 eposch...:  36%|███▋      | 73/200 [33:45<58:36, 27.69s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 73 eposch...:  37%|███▋      | 74/200 [34:12<58:06, 27.67s/it]
# Training 74 eposch...:  37%|███▋      | 74/200 [34:12<58:06, 27.67s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 74 eposch...:  38%|███▊      | 75/200 [34:40<57:40, 27.69s/it]
# Training 75 eposch...:  38%|███▊      | 75/200 [34:40<57:40, 27.69s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 75 eposch...:  38%|███▊      | 76/200 [35:08<57:09, 27.66s/it]
# Training 76 eposch...:  38%|███▊      | 76/200 [35:08<57:09, 27.66s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 76 eposch...:  38%|███▊      | 77/200 [35:36<57:21, 27.98s/it]
# Training 77 eposch...:  38%|███▊      | 77/200 [35:36<57:21, 27.98s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 77 eposch...:  39%|███▉      | 78/200 [36:04<56:37, 27.84s/it]
# Training 78 eposch...:  39%|███▉      | 78/200 [36:04<56:37, 27.84s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 78 eposch...:  40%|███▉      | 79/200 [36:31<55:57, 27.75s/it]
# Training 79 eposch...:  40%|███▉      | 79/200 [36:31<55:57, 27.75s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 79 eposch...:  40%|████      | 80/200 [36:59<55:22, 27.69s/it]
# Training 80 eposch...:  40%|████      | 80/200 [36:59<55:22, 27.69s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 80 eposch...:  40%|████      | 81/200 [37:26<54:43, 27.59s/it]
# Training 81 eposch...:  40%|████      | 81/200 [37:26<54:43, 27.59s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 81 eposch...:  41%|████      | 82/200 [37:54<54:08, 27.53s/it]
# Training 82 eposch...:  41%|████      | 82/200 [37:54<54:08, 27.53s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 82 eposch...:  42%|████▏     | 83/200 [38:21<53:43, 27.55s/it]
# Training 83 eposch...:  42%|████▏     | 83/200 [38:21<53:43, 27.55s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 83 eposch...:  42%|████▏     | 84/200 [38:49<53:13, 27.53s/it]
# Training 84 eposch...:  42%|████▏     | 84/200 [38:49<53:13, 27.53s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 84 eposch...:  42%|████▎     | 85/200 [39:16<52:47, 27.54s/it]
# Training 85 eposch...:  42%|████▎     | 85/200 [39:16<52:47, 27.54s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 85 eposch...:  43%|████▎     | 86/200 [39:44<52:20, 27.55s/it]
# Training 86 eposch...:  43%|████▎     | 86/200 [39:44<52:20, 27.55s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 86 eposch...:  44%|████▎     | 87/200 [40:11<51:47, 27.50s/it]
# Training 87 eposch...:  44%|████▎     | 87/200 [40:11<51:47, 27.50s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 87 eposch...:  44%|████▍     | 88/200 [40:39<51:24, 27.54s/it]
# Training 88 eposch...:  44%|████▍     | 88/200 [40:39<51:24, 27.54s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 88 eposch...:  44%|████▍     | 89/200 [41:07<50:57, 27.55s/it]
# Training 89 eposch...:  44%|████▍     | 89/200 [41:07<50:57, 27.55s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 89 eposch...:  45%|████▌     | 90/200 [41:34<50:31, 27.56s/it]
# Training 90 eposch...:  45%|████▌     | 90/200 [41:34<50:31, 27.56s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 90 eposch...:  46%|████▌     | 91/200 [42:02<50:02, 27.54s/it]
# Training 91 eposch...:  46%|████▌     | 91/200 [42:02<50:02, 27.54s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 91 eposch...:  46%|████▌     | 92/200 [42:29<49:43, 27.62s/it]
# Training 92 eposch...:  46%|████▌     | 92/200 [42:29<49:43, 27.62s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 92 eposch...:  46%|████▋     | 93/200 [42:57<49:10, 27.57s/it]
# Training 93 eposch...:  46%|████▋     | 93/200 [42:57<49:10, 27.57s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 93 eposch...:  47%|████▋     | 94/200 [43:24<48:40, 27.55s/it]
# Training 94 eposch...:  47%|████▋     | 94/200 [43:24<48:40, 27.55s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 94 eposch...:  48%|████▊     | 95/200 [43:52<48:20, 27.62s/it]
# Training 95 eposch...:  48%|████▊     | 95/200 [43:52<48:20, 27.62s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 95 eposch...:  48%|████▊     | 96/200 [44:20<47:46, 27.56s/it]
# Training 96 eposch...:  48%|████▊     | 96/200 [44:20<47:46, 27.56s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 96 eposch...:  48%|████▊     | 97/200 [44:47<47:10, 27.48s/it]
# Training 97 eposch...:  48%|████▊     | 97/200 [44:47<47:10, 27.48s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 97 eposch...:  49%|████▉     | 98/200 [45:15<46:46, 27.51s/it]
# Training 98 eposch...:  49%|████▉     | 98/200 [45:15<46:46, 27.51s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 98 eposch...:  50%|████▉     | 99/200 [45:42<46:19, 27.52s/it]
# Training 99 eposch...:  50%|████▉     | 99/200 [45:42<46:19, 27.52s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 99 eposch...:  50%|█████     | 100/200 [46:11<46:28, 27.89s/it]
# Training 100 eposch...:  50%|█████     | 100/200 [46:11<46:28, 27.89s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Training 100 eposch...:  50%|█████     | 101/200 [46:38<45:48, 27.77s/it]
# Training 101 eposch...:  50%|█████     | 101/200 [46:38<45:48, 27.77s/it]

# %% [markdown]
# ## Визуализация Эмбедингов

# %%
# !pip install umap-learn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting umap-learn
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      |████████████████████████████████| 88 kB 7.3 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from umap-learn) (1.21.6)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.7/dist-packages (from umap-learn) (1.0.2)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.7/dist-packages (from umap-learn) (1.4.1)
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.7/dist-packages (from umap-learn) (0.51.2)
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.7.tar.gz (1.1 MB)
#      |████████████████████████████████| 1.1 MB 58.8 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from umap-learn) (4.64.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.49->umap-learn) (57.4.0)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.49->umap-learn) (0.34.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from pynndescent>=0.5->umap-learn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22->umap-learn) (3.1.0)
# Building wheels for collected packages: umap-learn, pynndescent
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82829 sha256=2bdc6a07aa8fed67be230dfd2b553ed3d0e7b16c8a57fff78f5d634974d7b4dc
#   Stored in directory: /root/.cache/pip/wheels/b3/52/a5/1fd9e3e76a7ab34f134c07469cd6f16e27ef3a37aeff1fe821
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.7-py3-none-any.whl size=54286 sha256=48a7d3f33fc46cd9f33d0737d92b18c454af03e60f7d6733c3e04c3c2386bd09
#   Stored in directory: /root/.cache/pip/wheels/7f/2a/f8/7bd5dcec71bd5c669f6f574db3113513696b98f3f9b51f496c
# Successfully built umap-learn pynndescent
# Installing collected packages: pynndescent, umap-learn
# Successfully installed pynndescent-0.5.7 umap-learn-0.5.3

# %%
import seaborn as sns
import pandas as pd
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
import umap

def plot_embeddings(X, y, clustering_alg, alg_name):
    classes = len(num_to_class)
    est = clustering_alg(n_components=2)

    X_transform = est.fit_transform(X)
    # print(X_transform.shape)
    # print(y.shape)
    sns.set(rc={'figure.figsize':(11.7,8.27)})
    df = pd.DataFrame(zip(X_transform[:, 0], X_transform[:, 1], 
                          list(map(lambda t: num_to_class[str(t)], y))), 
                      columns=['X_0', 'X_1', 'y'])
    df['ind'] = df.index
    # print(df)
    # print(df.dtypes)
    sc = sns.scatterplot(data=df,
                    x='X_0',
                    y='X_1',
                    hue='y',
                    palette=sns.color_palette("husl", classes),
                    legend="brief")
    sc.set(title=alg_name)

# %%
model.eval()

for X_train, y_train in bef_train_data_loader:
    X_pred = model(X_train.cuda()).cpu().detach().numpy()
    plot_embeddings(X_pred, y_train.numpy(), TSNE, 'TSNE')
    plt.show()
    plot_embeddings(X_pred, y_train.numpy(), PCA, 'PCA')
    plt.show()
    plot_embeddings(X_pred, y_train.numpy(), umap.UMAP, 'UMAP')
